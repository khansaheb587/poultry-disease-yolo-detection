# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install ultralytics
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.108 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.7/112.6 GB disk)

# %%
# Import Libraries
import numpy as np
import pandas as pd
import os
import torch
from IPython.display import Image
import shutil
from random import choice
import yaml
import matplotlib.pyplot as plt
import random
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from google.colab import files
from ultralytics import YOLO
from IPython.display import HTML
from base64 import b64encode

# %%
# %cd /content/drive/MyDrive/YOLO
# Out:
# /content/drive/MyDrive/YOLO

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/YOLO/data.yaml' epochs=16 batch=16 project=/content/drive/MyDrive/YOLO/output name=result
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 5, in <module>
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/__init__.py", line 13, in <module>
#     from ultralytics.utils import ASSETS, SETTINGS
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/utils/__init__.py", line 26, in <module>
#     import torch
#   File "/usr/local/lib/python3.12/dist-packages/torch/__init__.py", line 2804, in <module>
#     from torch import _meta_registrations
#   File "/usr/local/lib/python3.12/dist-packages/torch/_meta_registrations.py", line 12, in <module>
#     from torch._decomp import (
#   File "/usr/local/lib/python3.12/dist-packages/torch/_decomp/__init__.py", line 288, in <module>
#     import torch._refs
#   File "/usr/local/lib/python3.12/dist-packages/torch/_refs/__init__.py", line 6617, in <module>
#     @register_decomposition(aten.vdot)
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/YOLO/output/result/weights/best.pt conf=0.6 source=/content/drive/MyDrive/YOLO/data/test/images
# Out:
# Ultralytics YOLOv8.2.15 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (1).jpg: 288x640 (no detections), 74.7ms
# image 2/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (10).jpg: 640x288 1 cocci, 70.7ms
# image 3/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (100).jpg: 640x288 1 cocci, 22.8ms
# image 4/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (11).jpg: 640x288 1 cocci, 36.8ms
# image 5/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (12).jpg: 640x288 (no detections), 22.8ms
# image 6/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (13).jpg: 288x640 1 cocci, 22.5ms
# image 7/371 /content/drive/MyDrive/YOLO/data/test/images/Test_cocci (14).jpg: 288x640 (no detections), 21.7ms
# ...

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/YOLO/data.yaml' epochs=20 batch=16 project=/content/drive/MyDrive/YOLO/output name=result
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/YOLO/data.yaml' epochs=16 batch=10 project=/content/drive/MyDrive/YOLO/output name=result
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Train
# !yolo task=detect mode=train model=yolov8m.pt imgsz=640 data='/content/drive/MyDrive/YOLO/data.yaml' epochs=20 batch=10 project=/content/drive/MyDrive/YOLO/output name=result
# Out:
# Ultralytics YOLOv8.2.18 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/YOLO/output/yolo8_poultry/weights/best.pt')
metrics = model.val(data='/content/drive/MyDrive/YOLO/data.yaml', split='test')

print(f"mAP@0.5: {metrics.box.map50:.4f}")
print(f"Inference speed: {metrics.speed['inference']:.2f} ms/image")
print(f"FPS: {1000/metrics.speed['inference']:.2f}")
# Out:
# Ultralytics 8.4.108 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 93 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 72.1±97.3 MB/s, size: 1124.2 KB)
# val: Scanning /content/drive/MyDrive/YOLO/data/test/labels... 131 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 131/131 1.1it/s 2:01
# val: New cache created: /content/drive/MyDrive/YOLO/data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.2s/it 10.4s
#                    all        131        156      0.907      0.803      0.905      0.481
#                  cocci         35         50      0.926      0.749      0.848       0.47
#                healthy         36         42      0.872      0.651      0.866      0.455
#                    ncd         29         31      0.938      0.903      0.964      0.462
# ...
